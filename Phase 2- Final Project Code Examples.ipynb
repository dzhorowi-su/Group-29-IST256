# %%
import googlemaps

gmaps = googlemaps.Client(key="AIzaSyAMr2LyirPDEmtlcZQVhwgzldWhkKgruM0")

#geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

#places = gmaps.place("restaurant", (43.0481, 76.1474))
#places
# Out:
# ---------------------------------------------------------------------------
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# _OverQueryLimit                           Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     259             else:
# --> 260                 result = self._get_body(response)
#     261             self.sent_times.append(time.time())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _get_body(self, response)
#     286             raise googlemaps.exceptions._OverQueryLimit(
# --> 287                 api_status, body.get("error_message"))
#     288
#
# _OverQueryLimit: OVER_QUERY_LIMIT (You have exceeded your daily request quota for this API. If you did not set a custom daily request quota, verify your project has an active billing account: http://g.co/dev/maps-no-account)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# <ipython-input-4-dc8682e98f40> in <module>
#       5 #geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')
#       6
# ----> 7 places = gmaps.place("restaurant", (43.0481, 76.1474))
#       8 places
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     363     def wrapper(*args, **kwargs):
#     364         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 365         result = func(*args, **kwargs)
#     366         try:
#     367             del args[0]._extra_params
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/places.py in place(client, place_id, session_token, fields, language)
#     384         params["sessiontoken"] = session_token
#     385
# --> 386     return client._request("/maps/api/place/details/json", params)
#     387
#     388
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     268             return self._request(url, params, first_request_time,
#     269                                  retry_counter + 1, base_url, accepts_clientid,
# --> 270                                  extract_body, requests_kwargs, post_json)
#     271
#     272     def _get(self, *args, **kwargs):  # Backwards compatibility.
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     208         elapsed = datetime.now() - first_request_time
#     209         if elapsed > self.retry_timeout:
# --> 210             raise googlemaps.exceptions.Timeout()
#     211
#     212         if retry_counter > 0:
#
# Timeout:
